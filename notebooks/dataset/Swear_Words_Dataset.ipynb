# %%
import pandas as pd

# %% [markdown]
# ## Datasets

# %%
english = pd.read_csv("/content/drive/MyDrive/Oracle_Research/Arion Research/Dataset/swear_words/local_language/csv/English_slangs.csv")
english.drop(columns=["Unnamed: 0"], axis=1, inplace=True)
english
# Out:
#          Swear_Word  Transliteration          English language
# 0    Son of a bitch   Son of a bitch   Son of a bitch  english
# 1      Cock muncher     Cock muncher     Cock muncher  english
# 2      Motherfucker     Motherfucker     Motherfucker  english
# 3             Whore            Whore            Whore  english
# 4          dickhead         dickhead         dickhead  english
# 5   Suck my Richard  Suck my Richard  Suck my Richard  english
# 6    Carpet muncher   Carpet muncher   Carpet muncher  english
# 7          Cuntface         Cuntface         Cuntface  english
# 8           Fuckwit          Fuckwit          Fuckwit  english
# 9   He is a Richard  He is a Richard  He is a Richard  english
# 10              Hoe              Hoe              Hoe  english
# 11          jackass          jackass          jackass  english
# 12        pigfucker        pigfucker        pigfucker  english
# 13          Bastard          Bastard          Bastard  english
# ...

# %%
spanish = pd.read_csv("/content/drive/MyDrive/Oracle_Research/Arion Research/Dataset/swear_words/local_language/csv/Spanish_slangs.csv")
spanish.drop(columns=["Unnamed: 0"], axis=1, inplace=True)
spanish
# Out:
#                    Swear_Word            Transliteration  \
# 0                       perra                      perra
# 1                        puta                       puta
# 2         Tu madre es un puta        Tu madre es un puta
# 3   Vete a chingar a tu madre  Vete a chingar a tu madre
# 4          cógete a ti mismo.         cógete a ti mismo.
# 5        Yo chingé a tu madre       Yo chingé a tu madre
# 6                 Come mierda                Come mierda
# 7       La madre que te parió      La madre que te parió
# 8                Hijo de puta               Hijo de puta
# 9              ¡Que te jodan!             ¡Que te jodan!
# 10     Tu cono huele a mierda     Tu cono huele a mierda
# 11                     pupila                     pupila
# 12                     piruja                     piruja
# 13                pinche puta                pinche puta
# 14             pinche pendejo             pinche pendejo
# ...

# %%
spanish.to_csv("/content/drive/MyDrive/Oracle_Research/Arion Research/Dataset/swear_words/local_language/csv/Spanish_slangs.csv")

# %%
french = pd.read_csv("/content/drive/MyDrive/Oracle_Research/Arion Research/Dataset/swear_words/local_language/csv/French_slangs.csv")
french.drop(columns=["Unnamed: 0"], axis=1, inplace=True)
french
# Out:
#                             Swear_Word                     Transliteration  \
# 0                   Va te faire foutre                  Va te faire foutre
# 1                               Salope                              Salope
# 2                               salope                              salope
# 3                        Nique ta mère                       Nique ta mère
# 4            Putain de bordel de merde           Putain de bordel de merde
# 5                      Ta mère la pute                     Ta mère la pute
# 6                        Fils de chien                       Fils de chien
# 7                         Fils de pute                        Fils de pute
# 8                          Trou du cul                         Trou du cul
# 9                             Connasse                            Connasse
# 10           Ferme ta putain de gueule           Ferme ta putain de gueule
# ...

# %%
french.to_csv("/content/drive/MyDrive/Oracle_Research/Arion Research/Dataset/swear_words/local_language/csv/French_slangs.csv")

# %%
german = pd.read_csv("/content/drive/MyDrive/Oracle_Research/Arion Research/Dataset/swear_words/local_language/csv/German_slangs.csv")
german.drop(columns=["Unnamed: 0"], axis=1, inplace=True)
german
# Out:
#                                     Swear_Word  \
# 0                                   Arschfotze
# 1                                   Arschgeige
# 2                                    Arschloch
# 3           Dein Hund soll deine Mutter ficken
# 4                               Dreckige Hure.
# 5                                 Du Hurensohn
# 6                 Du arschgefickter Hurensohn!
# 7                                    Fick dich
# 8                          Fick dich Arschloch
# 9                              Ficken Rossette
# 10                                      Ficker
# 11                                    Huan son
# 12                            Ich ficke Katzen
# 13                   Ich ficke deine Schwester
# 14                      Ich ficke deine Mutter
# 15                                Mottenficker
# 16                                  Nuttensohn
# 17                                      Pisser
# 18                              Schwanz lecker
# ...

# %%
german.to_csv("/content/drive/MyDrive/Oracle_Research/Arion Research/Dataset/swear_words/local_language/csv/German_slangs.csv")

# %%
hindi = pd.read_csv("/content/drive/MyDrive/Oracle_Research/Arion Research/Dataset/swear_words/local_language/csv/Hindi_slangs.csv")
hindi.drop(columns=["Unnamed: 0"], axis=1, inplace=True)
hindi
# Out:
#                   Swear_Word             Transliteration  \
# 0                      गांडू                      gaandu
# 1                        चूत                       choot
# 2                     बहनचोद                    Behen ke
# 3                     भोसड़ी                      Bhosdi
# 4                   भोसड़ीका                    bhosdika
# 5                  माँ चोदना                  Maa chodna
# 6                    मादरचोद                   Madarchod
# 7                       रंडी                       Randi
# 8              तेरी माँ रंडी               Teri ma randi
# 9                        लंड                        Lund
# 10                     लवड़ू                       Lavdu
# 11                      झाटू                       Jhatu
# 12                  ढीली चूत                 Dheeli chut
# 13                     दल्ले                       Dalle
# 14           तेरी माँ की चूत            teri maa ki chut
# ...

# %%
hindi.to_csv("/content/drive/MyDrive/Oracle_Research/Arion Research/Dataset/swear_words/local_language/csv/Hindi_slangs.csv")

# %%
marathi = pd.read_csv("/content/drive/MyDrive/Oracle_Research/Arion Research/Dataset/swear_words/local_language/csv/Marathi_slangs.csv")
marathi.drop(columns=["Unnamed: 0"], axis=1, inplace=True)
marathi
# Out:
#                      Swear_Word                Transliteration  \
# 0                           लंड                           Lund
# 1                      आईघाल्या                     Aai ghalya
# 2                       आईजवाडा                     Aai zawada
# 3                        आईझवली                      ai zawlee
# 4                        पुच्ची                          Puchi
# 5                      फोद्रीचा                       Fodricha
# 6                 बुल्ली चोक्या                   Bulli chokya
# 7              भडविच्याभिकारचोट          Bhadvichyabhikharchot
# 8                        भडव्या                        Bhadvya
# 9              तुझ्या आईचा लवडा             tuzya aaicha lavda
# 10                  फोडर फाट्या                  phodar phatya
# 11                       भोसडात                      Bhosadyat
# 12                      फोकनीचा                       Foknicha
# 13                     याडझव्या                       yadzavya
# ...

# %%
marathi.to_csv("/content/drive/MyDrive/Oracle_Research/Arion Research/Dataset/swear_words/local_language/csv/Marathi_slangs.csv")

# %%
bengali = pd.read_csv("/content/drive/MyDrive/Oracle_Research/Arion Research/Dataset/swear_words/local_language/csv/Bengali_slangs.csv")
bengali.drop(columns=["Unnamed: 0"], axis=1, inplace=True)
bengali
# Out:
#                     Swear_Word               Transliteration  \
# 0             বাবা চোদা রেন্ডি              Baba choda rendi
# 1                         বেশা                        Bessha
# 2                       বগা খা                     Boga Khaa
# 3                   চুদির পোলা                   Chudir Pola
# 4                  খানকির পোলা                  Khankir Pola
# 5                 কুতার বাচ্চা              Kuth-tar Bachcha
# 6            সুদুরিয়ার ফ্যুরি               SUDAURIER FURII
# 7                       সুডৌরি                       SUDAURY
# 8                  সুওরের বাছা               Suourer bachcha
# 9            তোর বাফোর বগা সাত           Tor Bafor Boga Saat
# 10             তোর বাফ ফেল খাই             Tor baaf fel Khai
# 11             তোর নানিরে চুদি              Tor nanire chudi
# 12              তোর মাইরে চুদি              Tor mayere chudi
# 13             আমার নুনু চ্যাট                amar nunu chat
# ...

# %%
bengali.to_csv("/content/drive/MyDrive/Oracle_Research/Arion Research/Dataset/swear_words/local_language/csv/Bengali_slangs.csv")

# %%
gujarati = pd.read_csv("/content/drive/MyDrive/Oracle_Research/Arion Research/Dataset/swear_words/local_language/csv/Gujarati_slangs.csv")
gujarati.drop(columns=["Unnamed: 0"], axis=1, inplace=True)
gujarati
# Out:
#                 Swear_Word             Transliteration  \
# 0         ઢીલા લંડ ની ઓલાદ        Dheela Lund Ni Olaad
# 1                  માદરચોડ                   Madarchod
# 2                કાળો લોડો                   Karo lodo
# 3                     લોડા                        loda
# 4                લોડે મારી                  lodde mari
# 5              માસી ચોદમનો               Masi Chodamno
# 6          મારા મન નો લાડો           mara mann no lado
# 7            મારી ગાંડ ચાટ            Mari gaand chaat
# 8                     રાંડ                       Raand
# 9                  ગાંડીના                    gaandina
# 10          મારી ભોસરી ચાટ           mari bhosri chaat
# 11      તારી માં ની પુટ્ટી            tari ma ni putti
# 12        તારી મા નો પોપલો            tari ma no poplo
# 13                  પિકીના                      pikina
# 14              નાગો ચોઇડો                 nago choido
# 15               ગાંડ તારી                  gaand tari
# ...

# %%
gujarati.to_csv("/content/drive/MyDrive/Oracle_Research/Arion Research/Dataset/swear_words/local_language/csv/Gujarati_slangs.csv")

# %% [markdown]
# ## Merge

# %%
dataframes = [english, spanish, french, german, hindi, marathi, bengali, gujarati]

merged_df = pd.concat(dataframes)
merged_df
# Out:
#                 Swear_Word             Transliteration  \
# 0           Son of a bitch              Son of a bitch
# 1             Cock muncher                Cock muncher
# 2             Motherfucker                Motherfucker
# 3                    Whore                       Whore
# 4                 dickhead                    dickhead
# ..                     ...                         ...
# 20                  બેનછોડ                     Benchod
# 21                    ચોડુ                       Chodu
# 22                  વેશ્યા                      veshya
# 23         તારી મા ને છોડુ           Tari maa ne chodu
# 24  તારી ગાંડ મા દંડો ગાલુ  taari gaand ma dando ghalu
#
#                             English  language
# 0                    Son of a bitch   english
# 1                      Cock muncher   english
# 2                      Motherfucker   english
# 3                             Whore   english
# 4                          dickhead   english
# ...

# %%
merged_df.to_csv("/content/drive/MyDrive/Oracle_Research/Arion Research/Dataset/swear_words/local_language/csv/All_swear_words.csv")

# %%
merged_df.to_excel("/content/drive/MyDrive/Oracle_Research/Arion Research/Dataset/swear_words/local_language/excel/All_swear_words.xlsx")
